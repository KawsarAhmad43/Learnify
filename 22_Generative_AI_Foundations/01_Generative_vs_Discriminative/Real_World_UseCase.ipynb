# %% [markdown]
# # Real World Use Case: Fraud Detection
#
# **Part 1: Discriminative (The Cop)**
# *   Train a classifier on past transactions to flag "Fraud" vs "Legit".
# *   Problem: You have very few examples of Fraud (0.1%).
#
# **Part 2: Generative (The Criminal Simulator)**
# *   Train a Generative Model to learn the distribution of *possible* fraudulent behaviors.
# *   Use it to generate 100,000 synthetic fraud cases.
# *   Train the Discriminator on this balanced dataset.
# **Result**: Robust fraud detection even for rare attacks.

# %%
print("Synthetic Data Generation is a primary use case involves GenAI in enterprise.")

# %% [markdown]
# ## Conclusion
# Discriminative models need Generative models to feed them data.
