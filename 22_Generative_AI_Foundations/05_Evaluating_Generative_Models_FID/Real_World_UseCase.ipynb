# %% [markdown]
# # Real World Use Case: Benchmarking Stable Diffusion
#
# **Scenario**: Assessing a new model.
# **Models**:
# 1.  **Model A (SD 1.5)**: Generates photo-realistic people but bad hands.
# 2.  **Model B (SD XL)**: Better lighting, better hands.
# **Metric**:
# *   We generate 30,000 images using prompts from the COCO dataset.
# *   We extract features using InceptionV3.
# *   We calculate FID against the real COCO images.
# *   **Result**:
#     *   SD 1.5 FID: 15.2
#     *   SD XL FID: 12.4
# **Decision**: We specify SD XL as the new SOTA (State Of The Art). FID relates strictly to human perception of quality.

# %%
print("Ranking: Low FID > High FID.")

# %% [markdown]
# ## Conclusion
# Without FID, we would depend on subjective "vibes" to evaluate models.
