# %% [markdown]
# # Solution: Loss Analysis
#
# **Objective**: Intuition.

# %%
# Theoretical Loss values
print("Ideal GAN Loss: log(0.5) + log(0.5) approx -1.38")
print("If D is perfect (acc=100%): Loss D approaches 0, Loss G explodes.")
print("If G is perfect (D=50%): Loss D is -1.38.")

# If Loss D stays at 0.00001 for 100 epochs, train D LESS or G MORE.
