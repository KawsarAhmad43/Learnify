# %% [markdown]
# # Solution: Budgeting
#
# **Objective**: Linear Algebra for PMs.

# %%
budget = 10.0
cost_gen = 0.01
cost_score = 0.001

N = budget / (cost_gen + cost_score)
print(f"Max N: {int(N)}")
