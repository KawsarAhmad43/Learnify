# %% [markdown]
# # Solution: VRAM
#
# **Objective**: Savings.

# %%
full_params = 16_777_216 * 4 # 4 bytes (FP32)
lora_params = 131_072 * 4

print(f"Full Weights: {full_params / 1024**2:.2f} MB")
print(f"LoRA Weights: {lora_params / 1024**2:.2f} MB")
print("Difference is 64MB vs 0.5MB per layer.")
