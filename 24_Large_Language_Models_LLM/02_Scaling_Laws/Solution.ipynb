# %% [markdown]
# # Solution: Optimal Sizing
#
# **Objective**: Algebra.

# %%
budget_flops = 1e23

# 120 * N^2 = Budget
N_squared = budget_flops / 120
N = N_squared ** 0.5

print(f"Optimal Param Count: {N / 1e9:.2f} Billion")
print("Training anything larger than this is a waste of money.")
