# %% [markdown]
# # Solution: GQA Savings
#
# **Objective**: Optimization.

# %%
cache_standard = 332 # GB
gqa_factor = 8 # Llama 3 uses 8x GQA

cache_optimized = cache_standard / gqa_factor

print(f"Optimized Cache: {cache_optimized:.2f} GB")
print("This fits on an 8-GPU cluster (H100s).")
