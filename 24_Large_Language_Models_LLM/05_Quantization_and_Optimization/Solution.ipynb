# %% [markdown]
# # Solution: Bandwidth Limit
#
# **Objective**: Hardware Reality.

# %%
bandwidth = 1000 # GB/s
model_size = 35 # GB

speed = bandwidth / model_size
print(f"Theoretical Max Speed: {speed:.2f} t/s")
print("If model was FP16 (140gb), speed would drop to:", bandwidth/140, "t/s")
