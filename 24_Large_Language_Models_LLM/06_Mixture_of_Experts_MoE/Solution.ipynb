# %% [markdown]
# # Solution: Throughput
#
# **Objective**: Savings.

# %%
dense_flops = 66
sparse_flops = 24

speedup = dense_flops / sparse_flops
print(f"Theoretical Speedup: {speedup:.2f}x")
print("In practice, routing overhead reduces this slightly, but it's still massive.")
