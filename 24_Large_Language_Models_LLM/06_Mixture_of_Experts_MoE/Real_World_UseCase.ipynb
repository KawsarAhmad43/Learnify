# %% [markdown]
# # Real World Use Case: GPT-4
#
# **Rumor**: GPT-4 is not a single giant model.
# **Architecture**: Likely a 16-way MoE with Top-2 gating.
# **Implication**:
# *   Total Parameter Count: ~1.8 Trillion.
# *   Inference Parameter Count: ~280 Billion.
# **Benefit**: It can have massive capacity (knows everything) but run cheaply enough to be a commercial product.
# **Downside**: High VRAM requirement (need to store all 1.8T params), but low Compute requirement.

# %%
print("MoE is the secret to scaling beyond 1 Trillion parameters.")

# %% [markdown]
# ## Conclusion
# Sparsity is efficiency.
