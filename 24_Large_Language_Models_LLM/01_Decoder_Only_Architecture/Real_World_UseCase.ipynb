# %% [markdown]
# # Real World Use Case: GitHub Copilot
#
# **Scenario**: Autocomplete Code.
# **Input**: `def factorial(n):`
# **Model**: OpenAI Codex (Decoder-Only).
# **Process**:
# 1.  It sees the prefix.
# 2.  It predicts `if` (Prob 90%).
# 3.  It adds `if` to the context.
# 4.  It predicts `n` (Prob 99%).
# 5.  Loop until `<|endoftext|>` token.
# **Result**: Writes the whole function body.
# **Why not BERT?**: BERT is bidirectional. It is great for *analyzing* code (Find bugs), but it cannot *generate* code sequentially.

# %%
print("Decoder-Only = Generation Specialists.")

# %% [markdown]
# ## Conclusion
# This architecture powers 99% of modern Generative AI text products.
