# %% [markdown]
# # Solution: Ranking
#
# **Objective**: Leaderboard Logic.

# %%
print("If Model A beats Model B 60% of time:")
print("Model A is significantly better.")
print("DPO works by effectively maximizing this Win Rate internally.")
