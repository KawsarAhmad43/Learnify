# %% [markdown]
# # Real World Use Case: Devin (Coding Agent)
#
# **Scenario**: "Fix the bug in repo X."
# **Workflow**:
# 1.  **Explore**: Agent runs `ls -R` to see files.
# 2.  **Hypothesize**: Reads `main.py`.
# 3.  **Test**: Runs `pytest`. Fails.
# 4.  **Edit**: Writes a patch to `utils.py`.
# 5.  **Verify**: Runs `pytest`. Passes.
# 6.  **Commit**: Pushes code.
# **Key**: It is an autonomous loop that can recover from errors (self-correction).

# %%
print("Agents turn LLMs from 'Consultants' into 'Employees'.")

# %% [markdown]
# ## Conclusion
# The future of software engineering is Agentic.
