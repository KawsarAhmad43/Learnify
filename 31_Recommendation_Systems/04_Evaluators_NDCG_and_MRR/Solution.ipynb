# %% [markdown]
# # Solution: Beyond Accuracy
#
# **Objective**: Long Term Value.

# %%
print("Optimize for SESSION time, not CLICK rate.")
print("Optimizing for Clicks leads to Clickbait.")
print("Optimizing for Dwell Time leads to doom-scrolling, but higher retention.")
