# %% [markdown]
# # Solution: Embeddings are Key
#
# **Objective**: Representation.

# %%
print("Don't feed raw IDs into DCN.")
print("Always map high-cardinality categorical features (User ID) to low-dimensional dense embeddings (Vector of size 64) first.")
print("Then feed the vectors into the Cross Network.")
