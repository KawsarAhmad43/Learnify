# %% [markdown]
# # Real World Use Case: YouTube
#
# **Scenario**: Recommend 1 video from 1 Billion videos.
# **Stage 1: Retrieval (Candidate Generation)**:
# *   Use Two-Tower model + ScaNN (Vector Search).
# *   Result: Select Top 1000 candidates. (Fast, Low Precision).
# **Stage 2: Ranking**:
# *   Use DCN (Cross Network) or Large Transformer on the 1000 candidates.
# *   Result: Select Top 10. (Slow, High Precision).
# **Result**: The user watches another cat video.

# %%
print("The Funnel: Billions -> Hundreds -> Tens.")

# %% [markdown]
# ## Conclusion
# Don't try to rank everything.
