# %% [markdown]
# # Solution: FAISS
#
# **Objective**: Tooling.

# %%
print("Facebook AI Similarity Search (FAISS).")
print("It uses quantization and clustering (Voronoi cells) to search billions of vectors in milliseconds.")
print("Without FAISS (or Milvus/Pinecone), Two-Tower models are useless in production.")
