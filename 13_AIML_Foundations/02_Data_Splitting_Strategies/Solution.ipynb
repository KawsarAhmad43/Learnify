# %% [markdown]
# # Data Splitting: Solutions

# %% [markdown]
# ## Task 1: Stratified Split

# %%
import numpy as np
from sklearn.model_selection import train_test_split

# Imbalanced Data
X = np.zeros((100, 2))
y = np.array([0]*90 + [1]*10)

# With Stratify
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

print("Train Ratios:")
print(np.unique(y_train, return_counts=True))
# Should be 72 zeros, 8 ones (9:1)

print("Test Ratios:")
print(np.unique(y_test, return_counts=True))
# Should be 18 zeros, 2 ones (9:1)

# %% [markdown]
# ## Task 2: Time Series Split

# %%
from sklearn.model_selection import TimeSeriesSplit

data = np.array([1, 2, 3, 4, 5, 6])
tscv = TimeSeriesSplit(n_splits=3)

for train_index, test_index in tscv.split(data):
    print("TRAIN:", train_index, "TEST:", test_index)
# Observe that Test is always 'future' relative to Train

# %% [markdown]
# ## Task 3: The Leakage Trap
# Applying a function (like normalization or feature selection) to the **whole** dataset before splitting allows information from the Test set (like its mean or variance) to influence the Training process. This gives the model a 'peek' at the answers, leading to over-optimistic results that fail in production. Always Split First.
