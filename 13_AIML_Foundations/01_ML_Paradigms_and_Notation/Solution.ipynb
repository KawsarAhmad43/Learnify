# %% [markdown]
# # ML Paradigms: Solutions

# %% [markdown]
# ## Task 1: Identify the Paradigm
# 1.  **Supervised Learning** (Classification) - Labels exist.
# 2.  **Unsupervised Learning** (Clustering) - No labels.
# 3.  **Reinforcement Learning** - Reward signal present.
# 4.  **Supervised Learning** (Regression) - Predicting continuous value.

# %% [markdown]
# ## Task 2: Notation Translation
# Given:
# ```python
# X = [[1, 2], [3, 4]]
# theta = [0.5, 0.5]
# ```
# *   **m** (examples): 2
# *   **n** (features): 2
# *   Equation: $h_\theta(x^{(1)}) = \theta^T \mathbf{x}^{(1)}$

# %% [markdown]
# ## Task 3: The Design Matrix

# %%
import numpy as np

# Columns: Size, Bedrooms
X = np.array([
    [2104, 3],
    [1600, 3],
    [2400, 3],
    [1416, 2]
])

# Labels (just for completeness)
y = np.array([400, 330, 369, 232])

print(f"Design Matrix X:\n{X}")
print(f"Shape of X: {X.shape}") # Should be (4, 2)
