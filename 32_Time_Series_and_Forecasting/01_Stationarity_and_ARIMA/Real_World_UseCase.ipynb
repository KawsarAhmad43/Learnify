# %% [markdown]
# # Real World Use Case: Supply Chain Demand
#
# **Scenario**: Walmart needs to know how many umbrellas to ship to Seattle next week.
# **Data**: Historical sales.
# **Seasonality**: It rains in November. Sales go up. This is a "Seasonal" ARIMA (SARIMA) problem.
# **Result**: Overstocking costs money (Storage). Understocking costs money (Lost Sales). SARIMA finds the balance.

# %%
print("Old school stats (ARIMA/Exponential Smoothing) still beat Deep Learning on simple univariate datasets.")

# %% [markdown]
# ## Conclusion
# Don't use a cannon to kill a mosquito.
