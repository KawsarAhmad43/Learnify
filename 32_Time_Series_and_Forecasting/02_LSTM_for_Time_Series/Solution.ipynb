# %% [markdown]
# # Solution: Data Leakage
#
# **Objective**: Correctness.

# %%
print("Time Series leakage is subtle.")
print("Do NOT scale/normalize your data using the Global Mean. Use the Training Mean only.")
print("Do NOT do random K-Fold Split. Use Time-Series Split (Train on Jan-Mar, Test on Apr).")
