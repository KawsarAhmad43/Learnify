# %% [markdown]
# # Real World Use Case: Energy Load Forecasting
#
# **Scenario**: The Power Grid needs to know how much electricity usually is needed at 6 PM.
# **Data**: Past usage, Temperature, Day of Week, Is Holiday?
# **Model**: LSTM or GRU.
# **Why**: Energy usage is highly non-linear (AC units turn on exponentially as heat rises).
# **Result**: Efficient power generation (fewer blackouts, less waste).

# %%
print("Deep Learning works best when you have Massive Data (High Frequency).")

# %% [markdown]
# ## Conclusion
# For small datasets (Monthly Sales), stick to ARIMA.
