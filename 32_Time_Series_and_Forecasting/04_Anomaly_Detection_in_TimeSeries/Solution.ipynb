# %% [markdown]
# # Solution: Matrix Profile
#
# **Objective**: Classic algorithm.

# %%
print("The Matrix Profile (STUMPY library) finds 'Discords' (subsequences that look least like any other subsequence).")
print("It is hyper-parameter free and exact. Use it before training complex Deep Learning models.")
