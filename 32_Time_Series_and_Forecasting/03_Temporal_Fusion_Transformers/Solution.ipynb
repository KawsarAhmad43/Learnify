# %% [markdown]
# # Solution: Gated Residual Network (GRN)
#
# **Objective**: Architecture.

# %%
print("TFT uses GRNs to skip features that are not useful.")
print("It learns a 'Gate' (Sigmoid) that suppresses noise.")
print("This is why it performs well even on small noisy datasets where other Transformers overfit.")
