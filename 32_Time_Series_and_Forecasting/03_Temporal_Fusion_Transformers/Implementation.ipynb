# %% [markdown]
# # Implementation: PyTorch Forecasting
#
# **Goal**: State of the Art.

# %%
print("Implementing TFT from scratch is 2000 lines of code.")
print("Use the 'pytorch_forecasting' library.")

# Mock Code
# from pytorch_forecasting import TemporalFusionTransformer, TimeSeriesDataSet
# dataset = TimeSeriesDataSet(
#     data, 
#     time_idx="time_idx", 
#     target="sales",
#     group_ids=["store_id"],
#     static_categoricals=["city"],
#     time_varying_known_reals=["price", "day_of_week"]
# )
# model = TemporalFusionTransformer.from_dataset(dataset)
# trainer.fit(model)

# %% [markdown]
# ## Conclusion
# TFT beat Amazon's DeepAR in several benchmarks.
