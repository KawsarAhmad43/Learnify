# %% [markdown]
# # Real World Use Case: Logistics (UPS/FedEx)
#
# **Scenario**: Integrating multiple data sources.
# **Data**:
# *   **Past**: Number of packages delivered.
# *   **Future Known**: Flight schedules.
# *   **Static**: Airport Capacity.
# **TFT Strength**: It explicitly handles "Future Known" inputs (Variable Selection Network). It knows that a Flight is scheduled for tomorrow and uses that to predict Tomorrow's load.
# **Result**: Better staffing.

# %%
print("TFT is the 'ResNet' of Time Series Forecasting.")

# %% [markdown]
# ## Conclusion
# It handles heterogeneity.
