# %% [markdown]
# # Solution: Prompt Engineering
#
# **Objective**: Create a Few-Shot Prompt.

# %%
prompt = """
Classify the sentiment of the following reviews:

Review: "This was the best movie ever!"
Sentiment: Positive

Review: "I fell asleep halfway through."
Sentiment: Negative

Review: "It was barely watchable."
Sentiment:"""

print("--- Final Prompt ---")
print(prompt)
print("\n--- Expected Generation ---")
print(" Negative")
