# %% [markdown]
# # Solution: Opacus
#
# **Objective**: Library support.

# %%
print("Meta's 'Opacus' library enables DP-SGD in PyTorch with 2 lines of code.")
print("privacy_engine.make_private(module=net, optimizer=opt, data_loader=loader, noise_multiplier=1.1, max_grad_norm=1.0)")
