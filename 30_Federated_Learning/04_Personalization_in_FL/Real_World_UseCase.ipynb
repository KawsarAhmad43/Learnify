# %% [markdown]
# # Real World Use Case: Healthcare FL
#
# **Scenario**: 10 Hospitals want to train a Tumor Detector.
# **Constraint**: Patient data cannot leave the hospital (HIPAA).
# **Problem**: Hospital A has a GE Scanner (Darker images). Hospital B has a Siemens Scanner (Lighter images).
# **Personalization**:
# *   Use FL to learn the "shape" of a tumor (Global).
# *   Use Local Fine-tuning to adapt to the specific lighting/contrast of that hospital's scanner.
# **Result**: A model that works everywhere, respecting local domain shifts.

# %%
print("FL allows collaboration between competitors.")

# %% [markdown]
# ## Conclusion
# Break down silos.
