# %% [markdown]
# # Solution: Knowledge Distillation
#
# **Objective**: One way transfer.

# %%
print("Instead of sending weights, send predictions.")
print("The Global Model acts as a Teacher, the Local Model acts as a Student.")
print("The Student tries to mimic the Teacher on public data, then fine-tunes on private data.")
