# %% [markdown]
# # Real World Use Case: Hey Siri
#
# **Scenario**: Apple wants to improve "Hey Siri" detection.
# **Data**: Audio recordings of people saying "Hey Siri".
# **Privacy**: Apple cannot see your raw audio embeddings.
# **SecAgg**: They use Homomorphic Encryption / Secure Aggregation.
# **Result**: The server learns to better detect the trigger word based on millions of users, but no Apple Engineer can ever retrieve a specific user's voice print.

# %%
print("Trust No One (not even the server).")

# %% [markdown]
# ## Conclusion
# Security is expensive (Communication overhead) but necessary.
