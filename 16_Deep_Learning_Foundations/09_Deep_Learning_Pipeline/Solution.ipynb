# %% [markdown]
# # Solution: Class Refactoring
#
# **Objective**: Clean OOP Code.

# %%
class Classifier:
    def __init__(self):
        self.w = 0.5
        self.b = 0.1
        
    def fit(self, X, y):
        print("Training... (Mocking update)")
        self.w += 0.1 # Mock update
        
    def predict(self, X):
        return X * self.w + self.b

# Usage
model = Classifier()
model.fit(None, None)
result = model.predict(10)
print(f"Prediction: {result}")
