# %% [markdown]
# # Solution: Robustness
#
# **Objective**: Security.

# %%
print("XAI is a double-edged sword.")
print("Hackers use XAI to generate attacks (White Box Attacks).")
print("Defenders use XAI to detect attacks.")
