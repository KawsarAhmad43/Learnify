# %% [markdown]
# # Real World Use Case: Radiology AI
#
# **Scenario**: AI detects Pneumonia from Chest X-Rays.
# **Grad-CAM**: Shows a heatmap overlay.
# **Success**: Heatmap highlights the lung opacity.
# **Failure (Clever Hans)**: Heatmap highlights the metal token in the corner (which indicates the patient is lying down/sick).
# **Action**: Crop the images to remove the metal tokens to force the model to look at the lungs.

# %%
print("XAI prevents medical malpractice.")

# %% [markdown]
# ## Conclusion
# Doctors will not use AI unless they can 'Audit' the decision.
