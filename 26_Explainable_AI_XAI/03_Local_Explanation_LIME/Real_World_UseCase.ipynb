# %% [markdown]
# # Real World Use Case: "Wolf vs Husky"
#
# **Scenario**: A famous paper showed a Classifier with 99% accuracy on Wolves vs Huskies.
# **LIME**: Visualized the "Superpixels" that contributed to the decision.
# **Discovery**: For "Wolf" predictions, the model was looking at the BACKGROUND (Snow). All wolf photos had snow. All husky photos were in gardens.
# **Result**: The model was actually a "Snow Detector".
# **Action**: Use XAI to debug data bias before deployment.

# %%
print("Trust, but Verify.")

# %% [markdown]
# ## Conclusion
# Accuracy is not enough.
