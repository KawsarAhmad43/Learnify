# %% [markdown]
# # Solution: Multicollinearity
#
# **Objective**: Awareness.

# %%
print("Always check correlation matrix before running Feature Importance.")
print("If two features are >0.9 correlated, drop one of them before training/explaining.")
