# %% [markdown]
# # Real World Use Case: Churn Prediction
#
# **Scenario**: Telco company wants to know why customers leave.
# **Model**: XGBoost trained on 500 features.
# **Global Explanation**:
# 1.  Top Feature: "Number of Support Calls".
# 2.  Second Feature: "Contract Duration".
# **Action**: The CEO realizes that bad customer support is the root cause. They invest in training support staff.
# **Outcome**: Churn drops by 5%.

# %%
print("Global explanations drive Business Strategy.")

# %% [markdown]
# ## Conclusion
# It tells you 'What' to fix.
