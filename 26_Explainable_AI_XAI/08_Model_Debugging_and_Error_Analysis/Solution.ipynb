# %% [markdown]
# # Solution: Unit Tests for Data
#
# **Objective**: Automation.

# %%
print("Tools like 'Great Expectations' or 'Deepchecks' automate slice discovery.")
print("They act as Unit Tests for your ML pipeline (e.g., assert accurancy(Night) > 0.8)")
