# %% [markdown]
# # Real World Use Case: Andrej Karpathy and the Stop Sign
#
# **Scenario**: Tesla Autopilot kept failing at a specific intersection.
# **Debugging**: They looked at the Top Loss cases.
# **Finding**: There was a large "Stop" sign painted on a Billboard (Advertisement), not a traffic sign.
# **Action**: They added a "Is Traffic Control Device?" classification head to distinguish Ads from Signs.
# **Lesson**: You don't fix AI by writing code; you fix it by looking at Data.

# %%
print("Data-Centric AI.")

# %% [markdown]
# ## Conclusion
# The dataset IS the code.
