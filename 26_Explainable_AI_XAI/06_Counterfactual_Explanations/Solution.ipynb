# %% [markdown]
# # Solution: Causal Constraints
#
# **Objective**: Logic.

# %%
print("When generating CFs, you must input a 'Causal Graph'.")
print("Rule: Age can only increase.")
print("Rule: Education Level cannot decrease.")
print("Rule: Race cannot change.")
