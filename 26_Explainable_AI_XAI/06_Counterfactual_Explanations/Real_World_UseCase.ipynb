# %% [markdown]
# # Real World Use Case: Fraud Alerts
#
# **Scenario**: Credit card transaction declined.
# **User**: "Why?? I have money!"
# **Bank AI**: "It was declined because it was 2am and in a different country."
# **Counterfactual**: "If the transaction had been at 10am, it would have been approved."
# **Result**: The user understands it's a security precaution, not a penalty for being poor.

# %%
print("Counterfactuals reduce user frustration.")

# %% [markdown]
# ## Conclusion
# Explainability is Customer Service.
