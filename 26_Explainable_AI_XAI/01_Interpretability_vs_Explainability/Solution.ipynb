# %% [markdown]
# # Solution: Correlation is not Causation
#
# **Objective**: Skepticism.

# %%
print("Be careful. XAI tools visualize what the model LOOKS at, not 'Truth'.")
print("If the model is biased (looking at the wrong thing), XAI will faithfully show you that bias.")
