# %% [markdown]
# # Real World Use Case: Hiring Bias
#
# **Scenario**: An AI resume screener rejects a candidate.
# **SHAP Plot**:
# *   Education: +5 points.
# *   Experience: +10 points.
# *   Zip Code: -20 points.
# **Interpretation**: The model is penalizing the candidate heavily because they live in a low-income neighborhood (Proxy for race/class).
# **Action**: This model is illegal under disparate impact laws. Retrain excluding Zip Code.

# %%
print("SHAP is the gold standard for Fairness Audits.")

# %% [markdown]
# ## Conclusion
# It shines a light on the darkest corners of the model.
