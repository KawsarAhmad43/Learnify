# %% [markdown]
# # Real World Use Case: AlphaFold
#
# **Scenario**: Predict 3D protein structure from Amino Acid sequence.
# **Graph**:
# *   Nodes = Amino Acids.
# *   Edges = Proximity in 3D space.
# **Innovation**: They used "Triangle Attention" (a form of GNN) to reason about geometric constraints.
# **Result**: Solved a 50-year-old Grand Challenge in Biology.
# **Impact**: Reviewing new drug candidates in days instead of years.

# %%
print("GNNs are revolutionizing Biology/Chemistry.")

# %% [markdown]
# ## Conclusion
# AI for Science.
