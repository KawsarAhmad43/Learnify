# %% [markdown]
# # Solution: Over-smoothing
#
# **Objective**: Depth Limits.

# %%
print("If you average milk and coffee 100 times, you just get a uniform beige liquid.")
print("If you run GCNs for 100 layers, all nodes become identical.")
print("Fix: Keep GCNs shallow (2-3 layers) or use Skip Connections (ResGCN).")
