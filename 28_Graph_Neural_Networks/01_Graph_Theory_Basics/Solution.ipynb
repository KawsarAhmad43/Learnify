# %% [markdown]
# # Solution: Node Degree
#
# **Objective**: Measures.

# %%
print("Degree: Number of edges connected to a node.")
print("Centrality: How important is this node? (Google PageRank).")
print("GNNs learn to calculate these metrics implicitly.")
