# %% [markdown]
# # Real World Use Case: Drug Interaction Prediction
#
# **Scenario**: Will Drug A react badly with Drug B?
# **Graph**:
# *   Nodes = Proteins in the human body.
# *   Edges = Biological pathways.
# **GAT Logic**: When Drug A hits Protein X, how does that ripple through the network?
# **Attention**: The model learns to focus ONLY on the specific pathway responsible for liver toxicity, ignoring the millions of unrelated connections.
# **Result**: Safer clinical trials.

# %%
print("GAT allows interpretability. We can visualize WHICH edges had high attention.")

# %% [markdown]
# ## Conclusion
# Attention is all you need (even for graphs).
