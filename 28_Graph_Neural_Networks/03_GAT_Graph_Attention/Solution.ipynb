# %% [markdown]
# # Solution: Graph Transformers
#
# **Objective**: Modern State of the Art.

# %%
print("GAT only attends to direct neighbors.")
print("Graph Transformers add 'Positional Encodings' (Laplacian Eigenvectors) and allow attending to ALL nodes in the graph, not just neighbors.")
print("This is O(N^2) but powerful for small graphs (molecules).")
