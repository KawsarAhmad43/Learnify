# %% [markdown]
# # Solution: AIF360
#
# **Objective**: Tooling.

# %%
print("IBM's AI Fairness 360 (AIF360) is the standard library.")
print("It implements preprocessing (Reweighing), in-processing (Adversarial), and post-processing (Calibrated EqOdds) algorithms.")
