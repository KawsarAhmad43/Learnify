# %% [markdown]
# # Real World Use Case: Amazon's Hiring Tool
#
# **Scenario**: Amazon built an AI to score resumes.
# **Finding**: It learned to penalize the word "Women's" (e.g., "Women's Chess Club Captain").
# **Why**: The training data (past 10 years of successful hires) was mostly male engineers.
# **Result**: They scrapped the tool. It was irredeemably biased by Historical Bias.
# **Lesson**: You cannot "unbias" a model if the ground truth labels themselves are biased.

# %%
print("Garbage In, Discrimination Out.")

# %% [markdown]
# ## Conclusion
# AI amplifies existing patterns. If the pattern is sexism, AI becomes a sexist.
