# %% [markdown]
# # Implementation: Fact-Sheet / Model Card
#
# **Goal**: Compliance Documentation.

# %%
model_card = {
    "Model Name": "LoanApprover-v1",
    "Author": "FinTech Corp",
    "Intended Use": "Assist loan officers in risk assessment.",
    "Limitations": "Not tested on applicants under 18 or non-residents.",
    "Training Data": "Historical loans 2010-2020 (US Only).",
    "Performance": {
        "Accuracy": "85%",
        "False Positive Rate": "10%"
    },
    "Ethical Considerations": "Checked for racial bias using demographic parity."
}

import json
print(json.dumps(model_card, indent=4))
print("\nThis document is mandatory for High Risk systems under the EU AI Act.")

# %% [markdown]
# ## Conclusion
# Documentation is as important as Code.
