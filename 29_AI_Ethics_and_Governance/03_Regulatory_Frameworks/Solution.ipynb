# %% [markdown]
# # Solution: Governance Board
#
# **Objective**: Process.

# %%
print("Every AI project needs a 'Go/No-Go' review.")
print("Questions: Is the data legal? Is the model biased? Is there a fallback?")
print("If the answer is No, do not deploy.")
