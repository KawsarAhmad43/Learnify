# %% [markdown]
# # Real World Use Case: Game Development
#
# **Scenario**: An RPG Game.
# **Class**: `Character`.
# **Objects**: `Hero`, `Enemy`, `NPC`.
# **Attributes**: `health`, `mana`, `inventory`.
# **Methods**: `attack()`, `heal()`, `trade()`.
# **Why OOP?**: It organizes code into logical units. Imagine managing 100 enemies using just lists and dictionaries. It would be a nightmare.

# %%
print("OOP maps code to the real world.")
