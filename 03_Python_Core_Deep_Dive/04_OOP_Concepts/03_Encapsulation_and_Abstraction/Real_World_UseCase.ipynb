# %% [markdown]
# # Real World Use Case: API Clients
#
# **Scenario**: Connecting to Stripe/AWS.
# **Encapsulation**: The `StripeClient` class handles the authentication, retries, and error parsing internally.
# **Abstraction**: The user just calls `client.charge(100)`. They don't need to know about HTTP headers, JSON serialization, or the underlying REST API endpoints.
# **Benefit**: If Stripe changes their API version, you update the Client class, and the user code remains unchanged.

# %%
print("Abstraction layers save sanity.")
