# %% [markdown]
# # Solution: Interfaces in Python
#
# **Objective**: Protocol.
# 1. **Java/C#**: Have explicit `interface` keyword.
# 2. **Python**: Uses `abc.ABC` with all methods decorated as `@abstractmethod`. Or, modern Python uses `typing.Protocol` (Structural Subtyping) where you don't even need to inherit from the base class, just match the signature.

# %%
print("Explicit is better than implicit. Use ABCs for strict contracts.")
