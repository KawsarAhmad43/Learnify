# %% [markdown]
# # Real World Use Case: UI Frameworks (Tkinter/PyQt)
#
# **Scenario**: Building a Button.
# **Inheritance**: `Button` inherits from `Widget`.
# **Widget**: Handles drawing on screen, positioning (x, y), and events.
# **Button**: Inherits all that logic and adds `onClick` behavior.
# **Polymorphism**: The `Screen` renderer just calls `widget.draw()` for every item in the list. It doesn't care if it's a Button, Textbox, or Slider.

# %%
print("GUI programming relies 100% on Inheritance.")
