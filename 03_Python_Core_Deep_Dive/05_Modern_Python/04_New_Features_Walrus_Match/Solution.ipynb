# %% [markdown]
# # Solution: Dictionary Merge
#
# **Objective**: Convenience.
# 1. **Old Way**: `z = {**x, **y}`.
# 2. **New Way (Python 3.9+)**: `z = x | y` (Union Operator).
# 3. **Update**: `x |= y` (In-place update).

# %%
print("Syntax sugar keeps the code sweet.")
