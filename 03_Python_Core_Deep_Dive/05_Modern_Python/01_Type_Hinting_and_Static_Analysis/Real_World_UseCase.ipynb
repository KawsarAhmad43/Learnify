# %% [markdown]
# # Real World Use Case: FastAPI
#
# **Scenario**: Building a Web API.
# **Framework**: FastAPI relies entirely on Type Hints.
# **Code**: `def create_user(user: User):`.
# **Magic**: FastAPI reads the `User` class (Pydantic model) and automatically:
# 1.  Validates the incoming JSON Request.
# 2.  Converts data types (String "25" -> Int 25).
# 3.  Generates Interactive Documentation (Swagger UI).
# **Result**: You write 50% less code because types handle validation.

# %%
print("Modern Python Frameworks extract logic from types.")
