# %% [markdown]
# # Solution: NamedTuple
#
# **Objective**: Lightweight alternative.
# 1. **NamedTuple**: `from typing import NamedTuple`. Similar to dataclass but creates a Tuple (Immutable by default, Memory efficient).
# 2. **Comparison**: Use `NamedTuple` for simple data structures that behave like tuples (indexing). Use `dataclass` for fully featured classes.

# %%
print("Python defaults to flexibility.")
