# %% [markdown]
# # Solution: Data Version Control (DVC)
#
# **Objective**: Versioning.

# %%
print("Code changes are tracked in Git.")
print("Data changes are tracked in DVC.")
print("Your CI/CD pipeline should allow you to 'checkout' the exact dataset used to train Model v1.0.")
