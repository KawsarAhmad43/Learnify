# %% [markdown]
# # Implementation: Mock GitHub Action
#
# **Goal**: Automation.

# %%
# build.yml simulation
def run_pipeline(code_change):
    print("1. Checkout Code...")
    print("2. Install Dependencies...")
    
    # 3. Test
    test_passed = True
    if "syntax_error" in code_change:
        test_passed = False
        
    if not test_passed:
        return "BUILD FAILED"
        
    # 4. Deploy
    return "DEPLOYED TO STAGING"

print(run_pipeline("def foo(): return 1"))
print(run_pipeline("def foo( syntax_error "))

# %% [markdown]
# ## Conclusion
# Fail fast. Fix fast.
