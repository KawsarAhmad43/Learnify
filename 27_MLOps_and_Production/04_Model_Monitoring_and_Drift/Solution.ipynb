# %% [markdown]
# # Solution: Evidently AI
#
# **Objective**: Visualization.

# %%
print("Tools like Evidently AI or Arize provide dashboards for drift.")
print("They plot the 'Distance' between Train and Prod distributions over time.")
