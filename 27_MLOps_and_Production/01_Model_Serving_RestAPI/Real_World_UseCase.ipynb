# %% [markdown]
# # Real World Use Case: Uber Eats ETA
#
# **Scenario**: You order Pizza.
# **Backend**:
# 1.  App calls `POST /eta` with {restaurant_loc, user_loc, time}.
# 2.  The API loads the 'ETA Prediction Model' (XGBoost).
# 3.  It calculates "35 mins".
# 4.  App displays the time.
# **Scale**: Uber handles millions of these requests per second. They use high-performance serving (C++/Go wrappers) and Load Balancers.

# %%
print("Latency matters. If the API takes 2 seconds to respond, the app feels broken.")

# %% [markdown]
# ## Conclusion
# The model is just one small part of a larger Distributed System.
