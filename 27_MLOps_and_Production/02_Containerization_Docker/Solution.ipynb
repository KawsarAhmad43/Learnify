# %% [markdown]
# # Solution: Docker Ignore
#
# **Objective**: Hygiene.

# %%
print("Always include a .dockerignore file.")
print("Exclude: .git, __pycache__, local datasets, credentials.")
print("This prevents leaking secrets into the image.")
