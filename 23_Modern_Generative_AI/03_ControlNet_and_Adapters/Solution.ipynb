# %% [markdown]
# # Solution: Canny Logic
#
# **Objective**: Simulation.

# %%
import numpy as np
import cv2 # If available, otherwise mock

try:
    # Mock data if cv2 not installed in env
    img = np.zeros((100, 100), dtype=np.uint8)
    img[20:80, 20:80] = 255 # White square
    
    # Edges would be the border of the square
    edges = np.zeros_like(img)
    edges[20, 20:80] = 255
    edges[80, 20:80] = 255
    edges[20:80, 20] = 255
    edges[20:80, 80] = 255
    
    print("Original: White Square")
    print("Edges: White Outline")
    print("The model learns: 'Where there is a white line, draw a boundary'.")
except:
    print("CV2 logic simulation.")
