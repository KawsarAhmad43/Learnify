# %% [markdown]
# # Real World Use Case: Architecture Visualization
#
# **Scenario**: Architect sketches a rough blueprint of a house on a napkin.
# **Problem**: Client can't visualize the final house.
# **Workflow**:
# 1.  Take photo of Napkin.
# 2.  Run `Canny Edge Detector` to extract lines.
# 3.  Feed Lines into `ControlNet-Canny`.
# 4.  Prompt: "Modern Villa, sunset, glass windows, photorealistic".
# **Result**: A photorealistic render that perfectly aligns with the napkin lines.
# **Benefit**: Iterate on designs in seconds, not hours.

# %%
print("ControlNet turned Generative AI from a toy into a professional tool.")

# %% [markdown]
# ## Conclusion
# Structure + Style = Product.
