# %% [markdown]
# # Solution: Batch Size Logic
#
# **Objective**: Constraints.

# %%
batch_size = 32000
negatives = batch_size - 1

print(f"For every positive pair, the model sees {negatives} negative examples.")
print("This dense supervision is why CLIP is so robust.")
