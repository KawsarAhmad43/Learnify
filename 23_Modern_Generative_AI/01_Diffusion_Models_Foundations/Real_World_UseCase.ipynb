# %% [markdown]
# # Real World Use Case: Denoising Old Photos
#
# **Scenario**: You have a grainy B&W photo from 1920.
# **Insight**: A Diffusion Model is trained to remove noise.
# **Method**:
# 1.  Take the grainy photo.
# 2.  Treat it as $x_{100}$ (Partially noisy image).
# 3.  Run the *Reverse Process* from $t=100$ down to $t=0$.
# **Result**: The model "hallucinates" clean details while respecting the structure of the grainy input.
# **Apps**: Restoration features in Photoshop / MyHeritage.

# %%
print("Diffusion models are basically Iterative Denoisers.")

# %% [markdown]
# ## Conclusion
# This is why they are so good at "image-to-image" translation.
