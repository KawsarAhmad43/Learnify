# %% [markdown]
# # Solution: Complexity
#
# **Objective**: Math.

# %%
tokens_256 = 128 * 128
tokens_512 = 256 * 256

ratio_tokens = tokens_512 / tokens_256
ratio_compute = ratio_tokens ** 2

print(f"Token Increase: {ratio_tokens}x")
print(f"Compute Increase: {ratio_compute}x (Attention Quadratic Bottleneck)")
