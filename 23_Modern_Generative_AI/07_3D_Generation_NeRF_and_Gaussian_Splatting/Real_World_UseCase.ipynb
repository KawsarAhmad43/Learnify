# %% [markdown]
# # Real World Use Case: Google Immersive View
#
# **Scenario**: 3D Maps.
# **Data**: Thousands of drone/satellite photos of Tokyo.
# **Method**: NeRF / Gaussian Splatting.
# **Result**: A photorealistic 3D city that you can fly through.
# **Why not Meshes?**: Traditional polygons struggle with trees, smoke, and reflections (transparent surfaces). NeRF handles transparency naturally via Density.

# %%
print("Neural Rendering is replacing Geometry in Computer Graphics.")

# %% [markdown]
# ## Conclusion
# We are moving from 'Modeling Triangles' to 'Modeling Light'.
