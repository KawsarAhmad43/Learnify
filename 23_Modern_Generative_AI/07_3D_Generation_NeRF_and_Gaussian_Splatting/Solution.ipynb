# %% [markdown]
# # Solution: Sorting Cost
#
# **Objective**: Algorithm Analysis.

# %%
import math

N = 1_000_000
comparisons = N * math.log2(N)

print(f"Ops (LogN): {comparisons:,}")
print("Ops (Linear Radix):", N * 32, "(Assuming 32-bit floats)")
print("Parallel Radix Sort is the hero of 3DGS.")
