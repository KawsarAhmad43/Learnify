# %% [markdown]
# # Real World Use Case: Midjourney (Creative Studio)
#
# **Scenario**: Game Studio needs concept art for a "Cyberpunk Samurai".
# **Old Workflow**: Artist spends 3 days painting one variation.
# **New Workflow**:
# 1.  Prompt Engineering: "Cyberpunk Samurai, Neon lights, rain, unreal engine 5 --ar 16:9".
# 2.  Stable Diffusion XL generates 4 variations in 30 seconds.
# 3.  Art Director picks #3.
# 4.  Artist does "Inpainting" (Masking the sword and re-generating it to look sharper).
# **Result**: 3 days of work compressed into 1 hour.

# %%
print("Generative AI acts as a multiplier for human creativity, not just a replacement.")

# %% [markdown]
# ## Conclusion
# Understanding prompts is key. '--ar' alters the latent size. 'Neon lights' triggers specific CLIP neurons.
