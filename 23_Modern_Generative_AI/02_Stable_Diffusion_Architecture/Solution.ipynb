# %% [markdown]
# # Solution: Compression Calculation
#
# **Objective**: Math.

# %%
pixels = 512 * 512 * 3
latents = 64 * 64 * 4

ratio = pixels / latents

print(f"Pixels: {pixels:,}")
print(f"Latents: {latents:,}")
print(f"Speedup Factor: {ratio}x")
