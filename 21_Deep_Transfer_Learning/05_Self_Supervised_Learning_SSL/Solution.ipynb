# %% [markdown]
# # Solution: Augmentation Check
#
# **Objective**: Reasoning.

# %%
good_augs = ["Horizontal Flip", "Color Jitter", "GaussianBlur"]
bad_aug = "Extreme Crop (Empty Background)"

print("Good Positives:", good_augs)
print("False Positive Risk:", bad_aug)

# In SimCLR, they found that composing Crop + Color Jitter is critical.
# Coping alone isn't enough because the model cheats by looking at color histograms.
