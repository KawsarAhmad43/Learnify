# %% [markdown]
# # Solution: Size Calculation
#
# **Objective**: Feasibility study.

# %%
base_size_gb = 140
opt_size_gb = 7 * 0.5

print(f"Base: {base_size_gb} GB")
print(f"Optimized: {opt_size_gb} GB")

if opt_size_gb < 16:
    print("Status: FITS on Laptop")
else:
    print("Status: Need Cloud GPU")
