# %% [markdown]
# # Solution: Guardrails
#
# **Objective**: Constraints.

# %%
print("Always parse the SQL output.")
print("If 'DROP' or 'DELETE' in sql_string: raise SecurityError.")
print("Text2SQL is powerful but requires strict sandboxing.")
