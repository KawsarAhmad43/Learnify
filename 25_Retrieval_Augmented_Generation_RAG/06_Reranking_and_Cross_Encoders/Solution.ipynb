# %% [markdown]
# # Solution: ColBERT
#
# **Objective**: Best of both worlds.

# %%
print("ColBERT (Contextualized Late Interaction) is an architecture that keeps vectors separate (like Bi-Encoder) but allows fine-grained interaction (like Cross-Encoder) via 'MaxSim' logic.")
print("It is 100x faster than Cross-Encoders with similar accuracy.")
