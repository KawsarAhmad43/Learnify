# %% [markdown]
# # Solution: Scaling
#
# **Objective**: Infrastructure.

# %%
dims = 1536
count = 1_000_000_000
bytes_per_dim = 4

total_gb = (count * dims * bytes_per_dim) / 1e9

print(f"Total RAM: {total_gb:.2f} GB")
print("Too big for one server. Must use Sharding (distributed DB).")
