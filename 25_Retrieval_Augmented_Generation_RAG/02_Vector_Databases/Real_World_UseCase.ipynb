# %% [markdown]
# # Real World Use Case: E-Commerce Search
#
# **Scenario**: User searches "Red summer dress for party".
# **Old Search (Keyword)**: Looks for "Red" AND "Summer" AND "Dress". Falls if product is named "Crimson Sundress".
# **New Search (Vector)**:
# 1.  Embed query: `[...values representing 'warm weather formal wear'...`
# 2.  Embed products.
# 3.  Matches "Crimson Sundress" because it lives in the same semantic neighborhood.
# **Result**: +15% conversion rate.
# **Tech Stack**: Pinecone + OpenAI Embeddings.

# %%
print("Vector Search solved the 'Vocabulary Mismatch' problem.")

# %% [markdown]
# ## Conclusion
# It understands *intent*, not just words.
