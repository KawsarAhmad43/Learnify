# %% [markdown]
# # Real World Use Case: Perplexity.ai / SearchGPT
#
# **Scenario**: User asks "Who won the last Super Bowl and what was the score?"
# **Workflow**:
# 1.  **Decompose**: "Identify last Super Bowl" -> "Find winner" -> "Find score".
# 2.  **Search**: Queries Google/Bing.
# 3.  **Read**: Scrapes top 3 links.
# 4.  **Synthesize**: Combines info into a coherent paragraph.
# 5.  **Cite**: Adds [1][2] footnotes.
# **Difference from Google**: It gives an Answer, not a List of Links.
# **Difference from ChatGPT**: It knows things that happened 5 minutes ago.

# %%
print("The Answer Engine > The Search Engine.")

# %% [markdown]
# ## Conclusion
# Agentic RAG is the future of Web Search.
