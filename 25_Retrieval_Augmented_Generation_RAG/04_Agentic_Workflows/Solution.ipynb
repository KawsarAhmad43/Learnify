# %% [markdown]
# # Solution: Query Transformations
#
# **Objective**: Better Recall.

# %%
print("HyDE (Hypothetical Document Embeddings): generate a fake answer, embed THAT, and search for documents similar to the fake answer.")
print("Multi-Query: Generate 3 variations of the question.")
print("Step-Back: Generate a more abstract version of the question.")
