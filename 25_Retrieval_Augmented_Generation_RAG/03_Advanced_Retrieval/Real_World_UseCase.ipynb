# %% [markdown]
# # Real World Use Case: Legal Discovery
#
# **Scenario**: Lawyer searches "Breach of contract in Case 202-45".
# **Challenge**:
# *   "Breach of contract" is a semantic concept (Vector).
# *   "Case 202-45" is an exact ID (Keyword).
# **Pure Vector**: Finds all breach cases, maybe misses 202-45.
# **Pure Keyword**: Finds 202-45, but maybe misses the specific breach clauses.
# **Hybrid Solution**: Finds documents that match BOTH criteria.
# **Result**: The lawyer finds the exact document in seconds.

# %%
print("Hybrid Search is mandatory for production RAG.")

# %% [markdown]
# ## Conclusion
# Never rely on Vector Search alone for precise identifiers.
