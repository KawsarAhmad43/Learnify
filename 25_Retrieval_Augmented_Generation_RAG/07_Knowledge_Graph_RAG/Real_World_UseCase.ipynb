# %% [markdown]
# # Real World Use Case: Money Laundering Detection
#
# **Scenario**: 50,000 documents (Bank Statements, Corporate Registrations).
# **Query**: "Are there any connections between Person A and Person B?"
# **Vector Search**: Returns nothing (no single document mentions both).
# **GraphRAG**:
# 1.  Doc 1: Person A owns Company X.
# 2.  Doc 2: Company X transferred money to Shell Corp Y.
# 3.  Doc 3: Shell Corp Y is registered to Person B.
# 4.  Graph finds the path: A -> Co X -> Shell Y -> B.
# **Result**: Fraud Ring detected.

# %%
print("GraphRAG connects the dots.")

# %% [markdown]
# ## Conclusion
# Information is not just data; it is relationships.
