# %% [markdown]
# # Solution: Amazon Braket
#
# **Objective**: Access to Hardware.
# 1. **Braket**: AWS service to run circuits on REAL hardware (IonQ, Rigetti, Oxford Quantum Circuits).
# 2. **Code**: Use the `braket` SDK or the PennyLane-Braket plugin.
#    `dev = qml.device('braket.aws.qubit', device_arn='arn:aws:braket:::device/qpu/ionq/aria-1', wires=2)`
# 3. **Cost**: You pay per shot. (Expensive!).

# %%
print("Don't run loops on real hardware unless you have grant money.")
