# %% [markdown]
# # Real World Use Case: Protein Folding
#
# **Scenario**: Alzheimer's Research.
# **Problem**: Proteins misfold and clump together (Plaques).
# **Solution**: Classic AlphaFold is great, but it's an approximation. Quantum Simulation can model the exact folding dynamics.
# **Company**: Google and Boehringer Ingelheim are collaborating on this.

# %%
print("Biology is just Chemistry. Chemistry is just Physics. Physics is Quantum.")

# %% [markdown]
# ## Conclusion
# First principles simulation.
