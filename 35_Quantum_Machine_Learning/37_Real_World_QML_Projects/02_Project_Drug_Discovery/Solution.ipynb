# %% [markdown]
# # Solution: QPE (Quantum Phase Estimation)
#
# **Objective**: Exact Solution.

# %%
print("VQE is an approximation (Heuristic).")
print("QPE gives the EXACT eigenvalue.")
print("Problem: QPE requires very deep circuits (Fault Tolerance). Can't run on NISQ.")
print("Future: QPE is the ultimate algorithm for Chemistry.")
