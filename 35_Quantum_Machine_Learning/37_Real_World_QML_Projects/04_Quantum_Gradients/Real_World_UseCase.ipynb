# %% [markdown]
# # Real World Use Case: Optimizing Control Pulses
#
# **Scenario**: Building a better Qubit.
# **Problem**: Gates like $X$ are implemented by microwave pulses. But the pulses are never perfect.
# **Solution**: Use Quantum Gradients to optimize the *Pulse Shape* itself (Optimal Control Theory / GRAPE algorithm).
# **Gradient**: We take the gradient of the "Fidelity" w.r.t pulse amplitude.
# **Result**: Higher fidelity gates, better quantum computers.

# %%
print("Recursive improvement: Using QML to build better QCs to run QML.")

# %% [markdown]
# ## Conclusion
# The loop closes.
