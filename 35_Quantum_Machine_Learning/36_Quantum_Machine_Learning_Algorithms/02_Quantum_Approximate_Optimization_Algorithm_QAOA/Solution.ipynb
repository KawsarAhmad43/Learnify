# %% [markdown]
# # Solution: Warm Start
#
# **Objective**: Hybrid Assistance.

# %%
print("QAOA is hard to train.")
print("Recursive QAOA (R-QAOA) helps by eliminating variables one by one.")
print("Warm Start: Initialize the QC with the solution from a classical algorithm (Goemans-Williamson approximation). Then let the QC refine it.")
