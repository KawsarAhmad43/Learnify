# %% [markdown]
# # Real World Use Case: Drug Discovery (Again)
#
# **Scenario**: Generating new molecules.
# **Model**: Quantum GAN (QGAN).
# **Generator**: A Quantum Circuit that outputs a distribution of molecular states.
# **Discriminator**: A Classical Neural Network that judges if the molecule is valid.
# **Advantage**: The Quantum Generator can explore the chemical space (Hilber space) more naturally than a classical generator.

# %%
print("QGANs are useful for loading data into quantum computers too.")

# %% [markdown]
# ## Conclusion
# Generative AI meets Quantum.
