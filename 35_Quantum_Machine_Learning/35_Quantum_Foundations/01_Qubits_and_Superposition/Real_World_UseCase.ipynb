# %% [markdown]
# # Real World Use Case: Random Number Generation (QRNG)
#
# **Scenario**: Cryptography.
# **Classic**: `random.random()` is Pseudo-Random. If you know the seed, you know the number.
# **Quantum**: Measuring a Qubit in superposition is TRULY random (according to the Copenhagen Interpretation of Physics).
# **Application**: Samsung released a phone (Galaxy Quantum) with a QRNG chip for ultra-secure banking.

# %%
print("God DOES play dice with the universe.")

# %% [markdown]
# ## Conclusion
# Nature is probabilistic.
