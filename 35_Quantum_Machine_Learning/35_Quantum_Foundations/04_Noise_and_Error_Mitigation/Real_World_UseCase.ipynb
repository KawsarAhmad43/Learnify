# %% [markdown]
# # Real World Use Case: Hardware Calibration
#
# **Scenario**: IBM Quantum Experience.
# **Daily Routine**: Every morning, the quantum computer is calibrated.
# **T1 Time**: How long a Qubit stays in $|1
# angle$ before relaxing to $|0
# angle$ (Energy relaxation).
# **T2 Time**: How long a Qubit stays in Superposition before losing phase (Dephasing).
# **Metric**: If your algorithm takes $50\mu s$ to run, but T1 is $40\mu s$, your algorithm will output garbage. You must optimize the circuit depth.

# %%
print("Know your hardware limits.")

# %% [markdown]
# ## Conclusion
# Speed is accuracy.
