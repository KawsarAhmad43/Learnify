# %% [markdown]
# # Solution: Topological Qubits
#
# **Objective**: The Holy Grail.

# %%
print("Microsoft approach: Build qubits out of Anyons (quasiparticles) braided together.")
print("Theory: Local noise cannot untie global knots.")
print("Result: Hardware-level Error Correction. (Still experimental).")
