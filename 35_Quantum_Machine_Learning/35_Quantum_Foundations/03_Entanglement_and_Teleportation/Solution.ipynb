# %% [markdown]
# # Solution: CHSH Inequality
#
# **Objective**: Proof.

# %%
print("How do we know Entanglement isn't just hidden variables?")
print("The CHSH Inequality Test involves measuring correlations at specific angles.")
print("Classical Physics Limit: 2.0")
print("Quantum Physics Limit: 2 * sqrt(2) = 2.82")
print("Run this test on a Quantum Computer to prove Einstein was wrong about 'Hidden Variables'.")
