# %% [markdown]
# # Solution: Uncomputation
#
# **Objective**: Garbage Collection.

# %%
print("If you use a temporary 'Ancilla' qubit to compute an intermediate result, it becomes entangled with your data.")
print("If you discard it, you destroy the interference.")
print("Solution: You must 'Uncompute' (apply the inverse circuit) to reset the Ancilla to |0> before discarding it.")
