# %% [markdown]
# # Real World Use Case: Optimizing Logistics
#
# **Scenario**: Traveling Salesman Problem (TSP).
# **Gate**: To solve this, we don't use AND/OR gates. We use Phase Gates to manipulate the probability amplitudes so that the "Wrong Answers" cancel each other out (Interference) and the "Right Answer" (Shortest Path) is amplified.
# **Hardware**: IBM Quantum System One (127 Qubits).

# %%
print("Quantum Computing is not about trying every possibility. It's about choreographing interference.")

# %% [markdown]
# ## Conclusion
# Interference is the key mechanism.
