# %% [markdown]
# # Solution: CMSIS-NN
#
# **Objective**: Low Level Optimization.

# %%
print("ARM provides a library called CMSIS-NN.")
print("It contains handwritten Assembly code to run Convolution on Cortex-M processors efficiently (SIMD instructions).")
print("TFLite uses this under the hood.")
