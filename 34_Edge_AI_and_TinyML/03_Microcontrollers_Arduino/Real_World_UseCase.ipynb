# %% [markdown]
# # Real World Use Case: Smart Shoes
#
# **Scenario**: Nike Adapt (Self-lacing shoes).
# **Hardware**: Tiny embedded chip inside the sole.
# **Model**: Classification of Gyroscope data: "Is the user stepping inside the shoe?" -> Tighten laces.
# **Latency**: Must be < 100ms.
# **Battery**: Must last months.
# **Solution**: TinyML running a simplified Decision Tree or Tiny Neural Net.

# %%
print("Ubiquitous Computing: AI in everything, even your shoes.")

# %% [markdown]
# ## Conclusion
# Invisible AI.
