# %% [markdown]
# # Implementation: TFLite Transfer Learning
#
# **Goal**: Personalization.

# %%
print("TFLite supports 'Signatures' for training.")
print("You define a 'train' function in your TensorFlow model, export it to TFLite.")
print("The Android app calls interpreter.run_signature('train', input, label).")
print("The weights are updated inside the TFLite file on the phone storage.")

# %% [markdown]
# ## Conclusion
# The device gets smarter the more you use it.
