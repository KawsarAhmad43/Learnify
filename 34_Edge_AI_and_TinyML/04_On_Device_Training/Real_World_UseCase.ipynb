# %% [markdown]
# # Real World Use Case: Keyboard Autocorrect
#
# **Scenario**: Learning slang.
# **Problem**: The global model implies "Duck" is a bird.
# **User**: Types "Duck" when they are angry.
# **Training**: The phone's keyboard observes the user correcting "Duck" to "F***".
# **Update**: The local model updates the probability P(F*** | Angry) > P(Duck | Angry).
# **Privacy**: This vocabulary change stays on the phone.

# %%
print("True personalization requires learning.")

# %% [markdown]
# ## Conclusion
# It's about Context.
