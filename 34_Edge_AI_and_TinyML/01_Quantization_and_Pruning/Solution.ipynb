# %% [markdown]
# # Solution: Lottery Ticket Hypothesis
#
# **Objective**: Theory.

# %%
print("The Hypothesis: A large network contains a smaller sub-network (Winning Ticket) that, if trained in isolation, would match the accuracy of the original.")
print("Pruning finds this ticket.")
