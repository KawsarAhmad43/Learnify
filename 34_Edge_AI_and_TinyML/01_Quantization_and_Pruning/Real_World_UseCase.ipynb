# %% [markdown]
# # Real World Use Case: 'Hey Google'
#
# **Scenario**: Wake Word Detection.
# **Constraint**: Must run on the DSP (Digital Signal Processor) of the phone, using micro-watts of power.
# **Solution**: Quantized 1-bit or 2-bit weights.
# **Result**: The battery doesn't drain, but the phone is always listening.

# %%
print("The smaller the model, the cooler the phone (literally).")

# %% [markdown]
# ## Conclusion
# Efficiency = Battery Life.
