# %% [markdown]
# # Real World Use Case: Instagram Filters
#
# **Scenario**: Neural Style Transfer on your face.
# **Constraint**: Real-time (30 FPS).
# **Hardware**: The GPU of an iPhone 8 vs an iPhone 14.
# **Solution**: CoreML (Apple's format). Instagram converts their PyTorch models to CoreML to use the Apple Neural Engine (NPU).
# **Result**: Smooth video effects without burning the battery.

# %%
print("If your app uses >1GB RAM, the OS will kill it.")

# %% [markdown]
# ## Conclusion
# Mobile development is a war for resources.
