# %% [markdown]
# # Solution: Netron
#
# **Objective**: Visualization.

# %%
print("Use 'https://netron.app' to visualize your exported ONNX or TFLite model.")
print("It shows the input names, output names, and layer connections.")
print("Essential for debugging input shape mismatches.")
