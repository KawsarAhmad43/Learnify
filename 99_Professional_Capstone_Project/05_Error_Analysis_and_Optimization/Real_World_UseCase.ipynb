# %% [markdown]
# # Real World Use Case: Human-in-the-Loop
#
# **Scenario**: Predictive Maintenance Dashboard.
# **Problem**: Mechanics are skeptical of AI.
# **Solution**: The dashboard doesn't just say "RED ALERT". It says:
# 1.  **Prediction**: Failure in 5 days.
# 2.  **Reason**: Vibration sensor 3 has increased by 40% in the last hour vs normal baseline.
# 3.  **Action**: Inspect Bearing #4.
# **Outcome**: Trust. The Mechanic inspects, sees the damage, and validates the model. The feedback loop closes.

# %%
print("Explainability bridges the gap between Math and Reality.")
