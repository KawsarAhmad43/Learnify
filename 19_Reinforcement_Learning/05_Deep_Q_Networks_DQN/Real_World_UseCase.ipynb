# %% [markdown]
# # Real World Use Case: Playing Atari
#
# **Scenario**: 2013 DeepMind breakthrough.
# **Input**: 4 stacked frames of pixels (to see movement).
# **Output**: Joystick movement (Up, Down, Left, Right).
# **Algorithm**: DQN.
# **Result**: Superhuman performance on Breakout, Space Invaders.

# %%
# Conceptual Architecture

print("Input: (Batch, 4 Frames, 84, 84)")
print("   |")
print(" Conv2D (32 filters, 8x8, stride 4)")
print("   |")
print(" Conv2D (64 filters, 4x4, stride 2)")
print("   |")
print(" Conv2D (64 filters, 3x3, stride 1)")
print("   |")
print(" Flatten")
print("   |")
print(" Dense (512)")
print("   |")
print(" Output (Total Actions)")

# %% [markdown]
# ## Conclusion
# It's just a CNN, but the loss function comes from the Q-Learning math ($ (Target - Predicted)^2 $).
