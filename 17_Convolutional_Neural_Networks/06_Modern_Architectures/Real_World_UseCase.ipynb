# %% [markdown]
# # Real World Use Case: The Standard Backbone
#
# **Scenario**: You want to solve a computer vision problem (Segmentation, Detection, Pose Estimation).
# **Advice**: Don't invent your own architecture. Just use ResNet-50.
# **Why?** It is the standard unit of measurement in AI research.

# %%
# Conceptual Check of Depth
# ResNet-50 vs VGG-19
resnet_depth = 50
vgg_depth = 19

# Parameters (approx)
resnet_params = 25_000_000
vgg_params = 143_000_000

ratio = vgg_params / resnet_params
print(f"VGG is {ratio:.1f}x heavier than ResNet, yet shallower.")
print("ResNet is deeper, smarter, yet lighter. This is why it's the industry standard.")
