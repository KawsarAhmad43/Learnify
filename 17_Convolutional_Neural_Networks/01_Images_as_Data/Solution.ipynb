# %% [markdown]
# # Solution: Cyan Filter
#
# **Objective**: Zero out the Red Channel.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_sample_image

# 1. Load
china = load_sample_image("china.jpg")

# 2. Copy
cyan_image = china.copy()

# 3. Zero out Red (Index 0)
cyan_image[:, :, 0] = 0

# 4. Plot
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(china)
plt.title("Original")
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(cyan_image)
plt.title("No Red (Cyan)")
plt.axis('off')

plt.show()
