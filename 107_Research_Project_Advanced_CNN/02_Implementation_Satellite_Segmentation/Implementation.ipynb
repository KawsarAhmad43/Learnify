# %% [markdown]
# # Comprehensive Research: Satellite Segmentation
#
# ## 1. Mask Analysis
# Segmentation models struggle if the object (Water) is too small. We calculate the "Pixel Ratio" of our training set.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Mock Mask (256x256)
mask = np.zeros((256, 256))
mask[100:150, 100:150] = 1 # Small square of water

ratio = mask.mean()
print(f"Water Coverage: {ratio:.2%}")

plt.figure(figsize=(6, 6))
plt.imshow(mask, cmap='gray')
plt.title("Ground Truth Mask")
plt.show()
