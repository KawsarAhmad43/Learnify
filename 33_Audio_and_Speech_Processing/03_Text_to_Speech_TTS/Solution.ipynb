# %% [markdown]
# # Solution: MelGAN / HiFi-GAN
#
# **Objective**: Vocoding.

# %%
print("Generating raw audio waveforms sample-by-sample (WaveNet) is slow (2 minutes for 1 second of audio).")
print("GAN-based Vocoders (HiFi-GAN) generate the whole waveform in parallel.")
print("This enables Real-Time Neural TTS.")
