# %% [markdown]
# # Solution: MixUp Augmentation
#
# **Objective**: Regularization.

# %%
print("Audio mixes linearly.")
print("If you overlay a Dog and a Cat, you hear both.")
print("MixUp: Create a new training example by averaging the pixels of Image A and Image B. Label = 0.5 A + 0.5 B.")
print("This works incredibly well for Spectrograms.")
