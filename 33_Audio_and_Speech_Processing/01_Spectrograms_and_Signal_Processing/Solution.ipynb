# %% [markdown]
# # Solution: Torchaudio
#
# **Objective**: GPU Acceleration.

# %%
print("Librosa is CPU only (Slow).")
print("For training networks, use 'torchaudio'. It runs on GPU and is differentiable.")
print("transform = torchaudio.transforms.MelSpectrogram().cuda()")
