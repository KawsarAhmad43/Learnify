# %% [markdown]
# # Implementation: Using Whisper
#
# **Goal**: Transcribe.

# %%
print("Installing whisper: pip install -U openai-whisper")

# Mock Code
# import whisper
# model = whisper.load_model("base")
# result = model.transcribe("audio.mp3")
# print(result["text"])

# %% [markdown]
# ## Conclusion
# Whisper is effectively 'Solved' for English. The error rate is below human level.
